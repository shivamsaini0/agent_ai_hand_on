# %% [markdown]
# #GEN_AI SERIES PART 1
# #--------------------------------------
#
# #STEP 1 : CALL OPEN API
# #STEP 2 DEFINE FUNCTION INPUTS/OUTPUT OR A RESPONSE
# #STEP 3 GENERATOR
# #STEP 4 CLEAN THE DATA
# #STEP 5 LOAD THE THE QUERY

# %%
pip install openai==2.14.0
# Out:
# Collecting openai==2.14.0
#   Using cached openai-2.14.0-py3-none-any.whl.metadata (29 kB)
# Collecting anyio<5,>=3.5.0 (from openai==2.14.0)
#   Using cached anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting distro<2,>=1.7.0 (from openai==2.14.0)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai==2.14.0)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai==2.14.0)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai==2.14.0)
#   Downloading pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Collecting sniffio (from openai==2.14.0)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai==2.14.0)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<5,>=4.11 (from openai==2.14.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai==2.14.0)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai==2.14.0)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==2.14.0)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai==2.14.0)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai==2.14.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3,>=1.9.0->openai==2.14.0)
#   Downloading pydantic_core-2.46.3-cp313-cp313-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai==2.14.0)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\shubh\appdata\roaming\python\python313\site-packages (from tqdm>4->openai==2.14.0) (0.4.6)
# Using cached openai-2.14.0-py3-none-any.whl (1.1 MB)
# Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 24.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, tqdm, sniffio, jiter, idna, h11, distro, certifi, annotated-types, typing-inspection, pydantic-core, httpcore, anyio, pydantic, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.13.0 certifi-2026.4.22 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.13 jiter-0.14.0 openai-2.14.0 pydantic-2.13.3 pydantic-core-2.46.3 sniffio-1.3.1 tqdm-4.67.3 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script distro.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script openai.exe is installed in 'c:\Users\shubh\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install openai python-dotenv
# Out:
# Requirement already satisfied: openai in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (2.14.0)
# Requirement already satisfied: python-dotenv in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (2.13.3)
# Requirement already satisfied: sniffio in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.13)
# Requirement already satisfied: certifi in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shubh\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\shubh\appdata\roaming\python\python313\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# step 1 #### call the open api 


import os
from openai import OpenAI
from dotenv import load_dotenv
import textwrap

# Load .env file
load_dotenv()

try:
    api_key = os.getenv("OPENAI_API_KEY")   #← reads from .env file
    if not api_key:
        raise ValueError("OPENAI_API_KEY not found in .env file")

    os.environ["OPENAI_API_KEY"] = api_key
    client = OpenAI()
    print("OpenAI client ready ")

except ValueError as e:
    print(f"Key not found: {e}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Key not found: OPENAI_API_KEY not found in .env file
